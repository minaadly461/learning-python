# %%
def happy_birthday( ):
  print("Happy birthday to you")
  print("you are old!")


happy_birthday()
# Out:
# Happy birthday to you
# you are old!

# %%
def print_happy_birthday(name,age):
  print(f'Happy bithday {name}')  
  print(f'you are {age} years old!')

# %%
print_happy_birthday("mina",21)
# Out:
# Happy bithday mina
# you are 21 years old!

# %%
def display_invoice(username , amount , date):
  print(f"Hello {username}")
  print(f"your bill is {amount} l.e")
  print(f"date : {date}")

# %%
display_invoice("mina",200 , "2/2/2026")
# Out:
# Hello mina
# your bill is 200 l.e
# date : 2/2/2026

# %%
def add(num1 , num2 ):
  return num1 + num2

def sub(num1 , num2 ):
  return num1 - num2

def multi(num1 , num2 ):
  return num1 * num2

def div(num1 , num2 ):
  return num1 / num2


z = add(21,25)
z
# Out:
# 46
