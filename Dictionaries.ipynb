# %%
capitals = {
  "Egypt":"Cairo",
  "SAU":"Ryad",
  "China":"Beiging",
  "Palastine":"elqods"
 }

# %%
help(capitals)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
# ...

# %%
capitals
# Out:
# {'Egypt': 'Cairo', 'SAU': 'Ryad', 'China': 'Beiging', 'Palastine': 'elqods'}

# %%
capitals["Egypt"]
# Out:
# 'Cairo'

# %%
capitals.get("Egypt")
# Out:
# 'Cairo'

# %%
capitals.get("EGPYT","NOT FOUND")
# Out:
# 'NOT FOUND'

# %%
capitals.pop("Egypt")
# Out:
# 'Cairo'

# %%
print(capitals.keys())
# Out:
# dict_keys(['SAU', 'China', 'Palastine'])

# %%
print(capitals.values())
# Out:
# dict_values(['Ryad', 'Beiging', 'elqods'])

# %%
for k in capitals.keys():
  print(k)
# Out:
# SAU
# China
# Palastine

# %%
for v in capitals.values():
  print(v)
# Out:
# Ryad
# Beiging
# elqods

# %%
for k , v in capitals.items():
  print(k,v)
# Out:
# SAU Ryad
# China Beiging
# Palastine elqods
