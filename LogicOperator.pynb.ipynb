# %%
# or logic operator
temp = 28 
is_raining = True 

if temp > 34 or temp <10 or is_raining:
  print("event is cancelled")

else : 
  print("event is still scheduled")
# Out:
# event is cancelled

# %%
# AND 


temp = 10 
is_sunny = True

if temp >= 28 and is_sunny:
  print("it is hot outside ")
  print("it is sunny")

elif temp < 10 and is_sunny:
  print("it is cold")
  print('it is sunny')

elif 28>temp>0 and is_sunny:
  print('it is normal and good ')
  print('it is sunny')
# Out:
# it is normal and good
# it is sunny
