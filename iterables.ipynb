# %%
numbers = [1,2,3,4]

for number in numbers : 
  print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
numbers = (1,2,3,4)


for number in numbers : 
  print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
numbers = {1,2,3,4}


for number in numbers : 
  print(number)
# Out:
# 1
# 2
# 3
# 4

# %%
name = "mina adly"

for char in name:
  print(char , end="")
# Out:
# mina adly

# %%
names = {
  1:"mina",
  2:"adly",
  3:"lahzy"
}


for k,v in names.items():
  print(k,v)
# Out:
# 1 mina
# 2 adly
# 3 lahzy
