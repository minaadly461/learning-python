# %% [markdown]
# # IF condition

# %%
age = int(input("please enter your age : "))

# %%
if age > 100:
  print("you are too old to sign up")

elif age > 18:
  print("you are signed up: ")

else :
  print("you should be greater than 18 to sign up ")
# Out:
# you are too old to sign up

# %%
response = input("Would you like Pizza ? (Y/N): ")

if response == "Y":
  print("you got a free pizza")

else : 
  print("no food for you")
# Out:
# you got a free pizza

# %%
name = input("Enter your username :")


if name =="":
  print("your didnot enter a valid username")

else : 
  print(f"Hello {name}")
# Out:
# Hello mina

# %%
for_sale =True

if for_sale:
  print("this item is for sale ")

else :
  print("this item is not for sale ")
# Out:
# this item is for sale
