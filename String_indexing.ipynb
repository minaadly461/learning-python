# %%
credit_card = "1234-5678-9012-8964"

print(credit_card[0])
# Out:
# 1

# %%
credit_card[5]
# Out:
# '5'

# %%
credit_card[0 : 4]
# Out:
# '1234'

# %%
credit_card[5:9]
# Out:
# '5678'

# %%
credit_card[:4]
# Out:
# '1234'

# %%
credit_card[5:]
# Out:
# '5678-9012-8964'

# %%
credit_card[-1]
# Out:
# '4'

# %%
credit_card[::3]
# Out:
# '146-184'

# %%
# reverse
credit_card[::-1]
# Out:
# '4698-2109-8765-4321'

# %%
last_digits = credit_card[-4 : ]
last_digits
# Out:
# '8964'
