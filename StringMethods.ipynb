# %%
name =  input("please enter your full nmae:")
result = len(name)

print(result)
# Out:
# 15

# %%
name.find('a')
# Out:
# 3

# %%
name[0]
# Out:
# 'm'

# %%
name.rfind('a')
# Out:
# 11

# %%
result = name . capitalize()
result
# Out:
# 'Mina adly lahzy'

# %%
result = name.title()
result
# Out:
# 'Mina Adly Lahzy'

# %%
result = name.upper()
result
# Out:
# 'MINA ADLY LAHZY'

# %%
result = result.lower()
result
# Out:
# 'mina adly lahzy'

# %%
name.isdigit()
# Out:
# False

# %%
name.isalpha()
# Out:
# False

# %%
number = input("please enter your phone number")

print(number.count('-'))
# Out:
# 4

# %%
result = number.replace('-',"")
result
# Out:
# '01276521350'

# %%
print(result.startswith('0'))
# Out:
# True

# %%
name = input("enter your name ")

result = name.strip()

# %%
result
# Out:
# 'mina    adly lahzy'

# %%
name = input("enter your name ")


result = name.strip().lower().replace("  "," ")

result
# Out:
# 'mina adly lahzy'

# %%
username = input("Enter your username")

if len(username)>12:
	print("your username cannot be more than 12 characters")

elif not username.find(' ') == -1:
	print('your usern name cannot have space')
	
elif not username.isalpha():
	print('your username cannot have digits')
	
else : 
	print(f'welcome {username}')
# Out:
# your username cannot have digits
